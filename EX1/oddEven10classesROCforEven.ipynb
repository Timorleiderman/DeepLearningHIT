# %% [markdown]
# # Tutorial No. 1

# %% [markdown]
# ## 1. Import Packages

# %%
import tensorflow
from keras.datasets import mnist
from keras.models import Sequential, Model
import keras.layers as layers
from keras.utils import to_categorical

from keras import optimizers
from keras.models import model_from_json
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from plot_confusion_matrix import plot_confusion_matrix
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2. Load Data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Change labels to one-hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

#y_train = (y_train[:,0::2] == 1)
#y_test = (y_test[:,0::2] == 1)

#y_train = np.array([[not item.any() , item.any()] for item in y_train])
#y_test = np.array([[not item.any() , item.any()] for item in y_test])

# Print shapes
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (60000, 28, 28)
# x_test shape: (10000, 28, 28)
# y_train shape: (60000, 10)
# y_test shape: (10000, 10)

# %% [markdown]
# ## 3. Define Parameters

# %%
num_of_clss = 10           # number of classes
hidden_size = 10           # number of neurons in the hidden layer
lr = 1e-3 #usually start from 10^-3                  # learning rate 
beta_1 =  0.9 #momentum speed usually 0.9               # beta 1 - for adam optimizer
beta_2 =  0.95 # divide the values in squre grads usually 0.99              # beta 2 - for adam optimizer
epsilon = 1e-7        # epsilon - for adam optimizer
epochs = 50                # number of epochs how many times iterate over the data 
bs = 128  #usually multiply by 2 16 32 64 128 # bach calc loss update params                 # batch size

# %% [markdown]
# ## 4. Build 2 Layers Network

# %%
#from tensorflow.python.keras import backend as k
from tensorflow.keras.models import Sequential
#from keras.layers import Activation, Dense ,Flatten
from tensorflow.keras.layers import Flatten, Dropout, Activation, Input, Dense, concatenate

in_dim = 28*28

model = Sequential()
model.add(Flatten())
model.add(Dense(hidden_size, input_dim=in_dim))
model.add(Activation('sigmoid'))
model.add(Dense(num_of_clss, input_dim=in_dim))
model.add(Activation('softmax'))

# %% [markdown]
# ##  5. Train the Model

# %%
# define the optimizer and compile the model

adam = optimizers.Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model, iterating on the data in batches
history = model.fit(x_train, y_train, validation_split=0.3, epochs=epochs, batch_size=bs)
# Out:
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/50
# 42000/42000 [==============================] - 1s 34us/sample - loss: 1.6285 - accuracy: 0.5598 - val_loss: 1.2223 - val_accuracy: 0.7547
# Epoch 2/50
# 42000/42000 [==============================] - 1s 17us/sample - loss: 1.0483 - accuracy: 0.7858 - val_loss: 0.8833 - val_accuracy: 0.8118
# Epoch 3/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.7995 - accuracy: 0.8208 - val_loss: 0.7051 - val_accuracy: 0.8355
# Epoch 4/50
# 42000/42000 [==============================] - 1s 17us/sample - loss: 0.6809 - accuracy: 0.8345 - val_loss: 0.6687 - val_accuracy: 0.8328
# Epoch 5/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.6279 - accuracy: 0.8340 - val_loss: 0.5706 - val_accuracy: 0.8518
# Epoch 6/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.5706 - accuracy: 0.8474 - val_loss: 0.5508 - val_accuracy: 0.8532
# Epoch 7/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.5392 - accuracy: 0.8560 - val_loss: 0.5155 - val_accuracy: 0.8621
# Epoch 8/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.5144 - accuracy: 0.8599 - val_loss: 0.4831 - val_accuracy: 0.8690
# Epoch 9/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.5128 - accuracy: 0.8563 - val_loss: 0.4985 - val_accuracy: 0.8618
# Epoch 10/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4879 - accuracy: 0.8629 - val_loss: 0.4879 - val_accuracy: 0.8611
# Epoch 11/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4780 - accuracy: 0.8665 - val_loss: 0.4638 - val_accuracy: 0.8696
# Epoch 12/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4551 - accuracy: 0.8731 - val_loss: 0.4985 - val_accuracy: 0.8563
# Epoch 13/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4612 - accuracy: 0.8702 - val_loss: 0.4735 - val_accuracy: 0.8628
# Epoch 14/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4705 - accuracy: 0.8645 - val_loss: 0.4573 - val_accuracy: 0.8702
# Epoch 15/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4568 - accuracy: 0.8669 - val_loss: 0.4727 - val_accuracy: 0.8553
# Epoch 16/50
# 42000/42000 [==============================] - 1s 17us/sample - loss: 0.4561 - accuracy: 0.8665 - val_loss: 0.4356 - val_accuracy: 0.8772
# Epoch 17/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4451 - accuracy: 0.8696 - val_loss: 0.4450 - val_accuracy: 0.8690
# Epoch 18/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4376 - accuracy: 0.8727 - val_loss: 0.4811 - val_accuracy: 0.8487
# Epoch 19/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4455 - accuracy: 0.8682 - val_loss: 0.4321 - val_accuracy: 0.8764
# Epoch 20/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4240 - accuracy: 0.8750 - val_loss: 0.4398 - val_accuracy: 0.8739
# Epoch 21/50
# 42000/42000 [==============================] - 1s 17us/sample - loss: 0.4315 - accuracy: 0.8754 - val_loss: 0.4533 - val_accuracy: 0.8667
# Epoch 22/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4200 - accuracy: 0.8795 - val_loss: 0.4465 - val_accuracy: 0.8704
# Epoch 23/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4285 - accuracy: 0.8756 - val_loss: 0.4440 - val_accuracy: 0.8746
# Epoch 24/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4205 - accuracy: 0.8818 - val_loss: 0.4335 - val_accuracy: 0.8787
# Epoch 25/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4099 - accuracy: 0.8827 - val_loss: 0.4251 - val_accuracy: 0.8767
# Epoch 26/50
# 42000/42000 [==============================] - 1s 17us/sample - loss: 0.4005 - accuracy: 0.8859 - val_loss: 0.4085 - val_accuracy: 0.8857
# Epoch 27/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4105 - accuracy: 0.8792 - val_loss: 0.4171 - val_accuracy: 0.8792
# Epoch 28/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4026 - accuracy: 0.8805 - val_loss: 0.4243 - val_accuracy: 0.8761
# Epoch 29/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4120 - accuracy: 0.8777 - val_loss: 0.4372 - val_accuracy: 0.8753
# Epoch 30/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4215 - accuracy: 0.8792 - val_loss: 0.4356 - val_accuracy: 0.8738
# Epoch 31/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4125 - accuracy: 0.8831 - val_loss: 0.4316 - val_accuracy: 0.8766
# Epoch 32/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4068 - accuracy: 0.8803 - val_loss: 0.4345 - val_accuracy: 0.8742
# Epoch 33/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4024 - accuracy: 0.8819 - val_loss: 0.4420 - val_accuracy: 0.8704
# Epoch 34/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4126 - accuracy: 0.8740 - val_loss: 0.4323 - val_accuracy: 0.8683
# Epoch 35/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4228 - accuracy: 0.8761 - val_loss: 0.4224 - val_accuracy: 0.8750
# Epoch 36/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4252 - accuracy: 0.8749 - val_loss: 0.4041 - val_accuracy: 0.8841
# Epoch 37/50
# 42000/42000 [==============================] - 1s 19us/sample - loss: 0.3900 - accuracy: 0.8872 - val_loss: 0.4130 - val_accuracy: 0.8799
# Epoch 38/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3930 - accuracy: 0.8860 - val_loss: 0.4096 - val_accuracy: 0.8841
# Epoch 39/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3834 - accuracy: 0.8871 - val_loss: 0.4058 - val_accuracy: 0.8827
# Epoch 40/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3945 - accuracy: 0.8834 - val_loss: 0.4022 - val_accuracy: 0.8865
# Epoch 41/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3839 - accuracy: 0.8874 - val_loss: 0.3969 - val_accuracy: 0.8876
# Epoch 42/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3832 - accuracy: 0.8853 - val_loss: 0.4058 - val_accuracy: 0.8794
# Epoch 43/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3996 - accuracy: 0.8856 - val_loss: 0.4557 - val_accuracy: 0.8672
# Epoch 44/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.4087 - accuracy: 0.8845 - val_loss: 0.4204 - val_accuracy: 0.8796
# Epoch 45/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3921 - accuracy: 0.8879 - val_loss: 0.3996 - val_accuracy: 0.8829
# Epoch 46/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3847 - accuracy: 0.8888 - val_loss: 0.4058 - val_accuracy: 0.8813
# Epoch 47/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3780 - accuracy: 0.8931 - val_loss: 0.3957 - val_accuracy: 0.8887
# Epoch 48/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3786 - accuracy: 0.8922 - val_loss: 0.3945 - val_accuracy: 0.8879
# Epoch 49/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3789 - accuracy: 0.8913 - val_loss: 0.4015 - val_accuracy: 0.8876
# Epoch 50/50
# 42000/42000 [==============================] - 1s 18us/sample - loss: 0.3764 - accuracy: 0.8914 - val_loss: 0.3880 - val_accuracy: 0.8861

# %% [markdown]
# ## 6. Visualize

# %%
# plot train and validation loss 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show(); plt.close()

# %% [markdown]
# ## 7. Model Evaluation

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

# Print results
print('test loss:', test_loss)
print('test accuracy:', test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test loss: 0.38580376024246216
# test accuracy: 0.8918

# %% [markdown]
# ## 8. Predict on Test Set

# %%
y_pred = model.predict(x_test)

# Confusion Matrix
cm = confusion_matrix(np.argmax(y_test,axis=1), np.argmax(np.round(y_pred),axis=1))
labels = ['class ' + str(i) for i in range(num_of_clss)] 
plot_confusion_matrix(cm,labels,title='Confusion Matrix',normalize=True)
# Out:
# Normalized confusion matrix
# [[9.75510204e+01 0.00000000e+00 0.00000000e+00 1.02040816e-01
#   0.00000000e+00 1.22448980e+00 5.10204082e-01 2.04081633e-01
#   3.06122449e-01 1.02040816e-01]
#  [2.11453744e+00 9.55066079e+01 8.81057269e-02 1.76211454e-01
#   0.00000000e+00 0.00000000e+00 3.52422907e-01 1.76211454e-01
#   1.58590308e+00 0.00000000e+00]
#  [8.91472868e+00 3.87596899e-01 8.23643411e+01 2.03488372e+00
#   1.25968992e+00 2.90697674e-01 6.78294574e-01 1.35658915e+00
#   2.71317829e+00 0.00000000e+00]
#  [6.03960396e+00 2.97029703e-01 1.88118812e+00 8.28712871e+01
#   2.97029703e-01 3.26732673e+00 0.00000000e+00 1.58415842e+00
#   3.36633663e+00 3.96039604e-01]
#  [5.09164969e+00 2.03665988e-01 4.07331976e-01 0.00000000e+00
#   8.86965377e+01 3.05498982e-01 6.10997963e-01 4.07331976e-01
#   8.14663951e-01 3.46232179e+00]
#  [1.15470852e+01 2.24215247e-01 8.96860987e-01 3.25112108e+00
#   6.72645740e-01 7.60089686e+01 6.72645740e-01 4.48430493e-01
#   5.71748879e+00 5.60538117e-01]
#  [6.68058455e+00 0.00000000e+00 6.26304802e-01 0.00000000e+00
#   1.35699374e+00 1.56576200e+00 8.92484342e+01 0.00000000e+00
#   5.21920668e-01 0.00000000e+00]
#  [3.01556420e+00 6.80933852e-01 1.55642023e+00 3.89105058e-01
#   7.78210117e-01 0.00000000e+00 0.00000000e+00 8.98832685e+01
#   2.91828794e-01 3.40466926e+00]
#  [6.87885010e+00 1.33470226e+00 9.24024641e-01 1.95071869e+00
#   9.24024641e-01 2.25872690e+00 5.13347023e-01 7.18685832e-01
#   8.36755647e+01 8.21355236e-01]
#  [3.76610505e+00 1.98216056e-01 9.91080278e-02 4.95540139e-01
#   6.44202180e+00 1.28840436e+00 0.00000000e+00 2.08126858e+00
#   1.09018831e+00 8.45391477e+01]]
# [[ 956    0    0    1    0   12    5    2    3    1]
#  [  24 1084    1    2    0    0    4    2   18    0]
#  [  92    4  850   21   13    3    7   14   28    0]
#  [  61    3   19  837    3   33    0   16   34    4]
#  [  50    2    4    0  871    3    6    4    8   34]
#  [ 103    2    8   29    6  678    6    4   51    5]
#  [  64    0    6    0   13   15  855    0    5    0]
#  [  31    7   16    4    8    0    0  924    3   35]
#  [  67   13    9   19    9   22    5    7  815    8]
#  [  38    2    1    5   65   13    0   21   11  853]]

# %% [markdown]
# ## 9. Summerize

# %%
# Summerize the model arhiteture and parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  7850
# _________________________________________________________________
# activation (Activation)      multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  110
# _________________________________________________________________
# activation_1 (Activation)    multiple                  0
# =================================================================
# Total params: 7,960
# Trainable params: 7,960
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 10. Save the Model with the Learned Weights

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## 11. Load Saved Model

# %%
# load json and create model

json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
from tensorflow.keras import models

loaded_model = tensorflow.keras.models.model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# ## 12. Predict using Loaded Model

# %%
y_pred = loaded_model.predict(x_test)

# Confusion Matrix
cm = confusion_matrix(np.argmax(y_test,axis=1), np.argmax(np.round(y_pred),axis=1))
labels = ['class ' + str(i) for i in range(num_of_clss)] 
plot_confusion_matrix(cm,labels,title='Confusion Matrix',normalize=True)
# Out:
# Normalized confusion matrix
# [[9.75510204e+01 0.00000000e+00 0.00000000e+00 1.02040816e-01
#   0.00000000e+00 1.22448980e+00 5.10204082e-01 2.04081633e-01
#   3.06122449e-01 1.02040816e-01]
#  [2.11453744e+00 9.55066079e+01 8.81057269e-02 1.76211454e-01
#   0.00000000e+00 0.00000000e+00 3.52422907e-01 1.76211454e-01
#   1.58590308e+00 0.00000000e+00]
#  [8.91472868e+00 3.87596899e-01 8.23643411e+01 2.03488372e+00
#   1.25968992e+00 2.90697674e-01 6.78294574e-01 1.35658915e+00
#   2.71317829e+00 0.00000000e+00]
#  [6.03960396e+00 2.97029703e-01 1.88118812e+00 8.28712871e+01
#   2.97029703e-01 3.26732673e+00 0.00000000e+00 1.58415842e+00
#   3.36633663e+00 3.96039604e-01]
#  [5.09164969e+00 2.03665988e-01 4.07331976e-01 0.00000000e+00
#   8.86965377e+01 3.05498982e-01 6.10997963e-01 4.07331976e-01
#   8.14663951e-01 3.46232179e+00]
#  [1.15470852e+01 2.24215247e-01 8.96860987e-01 3.25112108e+00
#   6.72645740e-01 7.60089686e+01 6.72645740e-01 4.48430493e-01
#   5.71748879e+00 5.60538117e-01]
#  [6.68058455e+00 0.00000000e+00 6.26304802e-01 0.00000000e+00
#   1.35699374e+00 1.56576200e+00 8.92484342e+01 0.00000000e+00
#   5.21920668e-01 0.00000000e+00]
#  [3.01556420e+00 6.80933852e-01 1.55642023e+00 3.89105058e-01
#   7.78210117e-01 0.00000000e+00 0.00000000e+00 8.98832685e+01
#   2.91828794e-01 3.40466926e+00]
#  [6.87885010e+00 1.33470226e+00 9.24024641e-01 1.95071869e+00
#   9.24024641e-01 2.25872690e+00 5.13347023e-01 7.18685832e-01
#   8.36755647e+01 8.21355236e-01]
#  [3.76610505e+00 1.98216056e-01 9.91080278e-02 4.95540139e-01
#   6.44202180e+00 1.28840436e+00 0.00000000e+00 2.08126858e+00
#   1.09018831e+00 8.45391477e+01]]
# [[ 956    0    0    1    0   12    5    2    3    1]
#  [  24 1084    1    2    0    0    4    2   18    0]
#  [  92    4  850   21   13    3    7   14   28    0]
#  [  61    3   19  837    3   33    0   16   34    4]
#  [  50    2    4    0  871    3    6    4    8   34]
#  [ 103    2    8   29    6  678    6    4   51    5]
#  [  64    0    6    0   13   15  855    0    5    0]
#  [  31    7   16    4    8    0    0  924    3   35]
#  [  67   13    9   19    9   22    5    7  815    8]
#  [  38    2    1    5   65   13    0   21   11  853]]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# Plot linewidth.
lw = 2

even_odd =  [[value[0::2].any(), value[1::2].any()] for value in y_test]

pred_even_odd = [[sum(value[0::2]), sum(value[1::2])] for value in y_pred]

    
# Compute ROC curve and ROC area for each class
fpr, tpr, threshold = roc_curve(np.array(even_odd)[:,0].astype(int), np.array(pred_even_odd)[:,0])
roc_auc = auc(fpr, tpr)

# Plot all ROC curves
#colors = ['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'blue', 'black', 'brown', 'purple', 'pink']
#for i, color in zip(range(num_of_clss), colors):
plt.plot(fpr, tpr, color='aqua', lw=lw,label='ROC of even numbers (AUC = {0})' ''.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic ROC')
plt.legend(loc="lower right")
plt.show()

# %%
even_odd = []
for idx, value in enumerate(y_test):
    even_odd.append([value[0::2].any(), value[1::2].any()])

pred_even_odd = []
for idx, value in enumerate(y_pred):
    pred_even_odd.append([sum(value[0::2]), sum(value[1::2])])

# %%
y_pred.shape
# Out:
# (10000, 10)

# %%
even_odd =
even_odd
# Out:
# [[False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [True, False],
#  [False, True],
#  [False, True],
#  [True, False],
#  [False, True],
#  [True, False],
#  [True, False],
#  [True, False],
#  [True, False],
#  [False, True],
#  ...]
